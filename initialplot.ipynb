# %% [raw]
# cd

# %%
cd Desktop
# Out:
# C:\Users\DELL\Desktop

# %%
cd Intern
# Out:
# C:\Users\DELL\Desktop\Intern

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
dataset = pd.read_csv('C:/Users/DELL/Desktop/Intern/AAPL.csv',index_col="Date",parse_dates=True)

# %%
dataset.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-05-26  132.600006  132.910004  129.119995  129.619995  119.458923
# 2015-05-27  130.339996  132.259995  130.050003  132.039993  121.689232
# 2015-05-28  131.860001  131.949997  131.100006  131.779999  121.449577
# 2015-05-29  131.229996  131.449997  129.899994  130.279999  120.067184
# 2015-06-01  130.279999  131.389999  130.050003  130.539993  120.306801
#
#               Volume
# Date
# 2015-05-26  70697600
# 2015-05-27  45833200
# 2015-05-28  30733300
# 2015-05-29  50884500
# 2015-06-01  32112800

# %%
dataset.isna().any()
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2015-05-26 to 2020-05-22
# Data columns (total 6 columns):
# Open         1259 non-null float64
# High         1259 non-null float64
# Low          1259 non-null float64
# Close        1259 non-null float64
# Adj Close    1259 non-null float64
# Volume       1259 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 68.9 KB

# %%
dataset['Open'].plot(figsize=(20,6))

# %%
# 7 day rolling mean
dataset.rolling(30).mean().head(50)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-05-26         NaN         NaN         NaN         NaN         NaN
# 2015-05-27         NaN         NaN         NaN         NaN         NaN
# 2015-05-28         NaN         NaN         NaN         NaN         NaN
# 2015-05-29         NaN         NaN         NaN         NaN         NaN
# 2015-06-01         NaN         NaN         NaN         NaN         NaN
# 2015-06-02         NaN         NaN         NaN         NaN         NaN
# 2015-06-03         NaN         NaN         NaN         NaN         NaN
# 2015-06-04         NaN         NaN         NaN         NaN         NaN
# 2015-06-05         NaN         NaN         NaN         NaN         NaN
# 2015-06-08         NaN         NaN         NaN         NaN         NaN
# 2015-06-09         NaN         NaN         NaN         NaN         NaN
# 2015-06-10         NaN         NaN         NaN         NaN         NaN
# ...

# %%
dataset['Open'].plot(figsize=(20,6))
dataset.rolling(window=30).mean()['Close'].plot()

# %%
#gives moving average for past 30 days .....the payina bomma

# %%
dataset['Close: 30 Day Mean'] = dataset['Close'].rolling(window=30).mean()
dataset[['Close','Close: 30 Day Mean']].plot(figsize=(20,6))

# %%
dataset['Close'].expanding(min_periods=15).mean().plot(figsize=(16,6))

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)
